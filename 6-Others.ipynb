# %% [markdown]
# # Data Preparation

# %%
# Imports
import gzip
import shutil
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read File

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read merged dataFrame with Outliers removed
file='/content/drive/MyDrive/Master-VIU/09MIAR_TFM/Tumor-Educated_Platelets/data/IntVeld2022/DataPatientsWithGTNoOutliers.csv'
df = pd.read_csv(file,sep=';',index_col=0, na_values='n.a.', dtype={'Stage': 'object', 'Age': 'float64'})

# %%
df.shape
# Out:
# (2349, 5261)

# %%
column_list = df.columns

# %%
# df_sex = df['Sex']
# df_age = df['Age']
# df_class = df['Class_group']

# %%
df.groupby('Sex').size().plot(kind='pie', autopct='%.2f', colors='mc')
plt.ylabel('Género', fontsize=15)
plt.show()

# %%
df.groupby('Class_group').size().plot(kind='pie', autopct='%.2f', colors='rg')
plt.ylabel('Clase', fontsize=15)
plt.show()

# %%
bins = [0,18,30,45,65,80,100]
df.groupby(pd.cut(df.Age, bins)).size().plot(kind='pie', autopct='%.2f')
plt.ylabel('Edad', fontsize=15)
plt.show()
